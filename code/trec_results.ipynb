# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.doc2vec import Doc2Vec
from tqdm import tqdm
from bs4 import BeautifulSoup as bs
import sys
import os
import numpy as np
import json
import random
import re
import pytrec_eval

# %%
def get_query_map(dataset,cluster):
    
    query_map = {}
    
    if (dataset == "ap"):
        if (cluster=="kmeans"):
            filename = "K-Means_Bert_AP.txt"
        else:
            filename = "Clarans_Bert_AP.txt"
    else:
        if (cluster == "kmeans"):
            filename = "K-Means_Bert_ZF.txt"
        else:
            filename = "Clarans_Bert_ZF.txt"
            
    with open(os.path.join("Rankings",filename),"r") as o:
        lines = o.readlines()
        text = " ".join(lines)
        text = text.split("\n")

        for line in text:
            words = line.split()
            if (len(words)==3):
                qno = words[0]
                doc = words[1]
                score = words[2]
                if str(int(qno)) in query_map:
                    query_map[str(int(qno))][doc] = float(score)
                else:
                    query_map[str(int(qno))] = {doc:float(score)}
                
    return query_map

# %%
run = get_query_map("ap","kmeans")

# %%
def loadScores():  
    true_scores = {}
    with open("trec12-news.tsv") as f:
        lines = f.read().splitlines()
        for line in lines:
            words = re.split(" |\t", line)
            query_id = words[0]
            doc_id = words[2]
            if query_id in true_scores:
                true_scores[query_id][doc_id] = 1
            else:
                true_scores[query_id] = {doc_id:1}
    return true_scores

# %%
qrels = loadScores()

# %%
def getQrels(qrels):
    filename = "qrels.txt"
    with open(filename,"w") as o:
        for qno in qrels:
            for doc in qrels[qno]:
                o.write(qno+" "+"0"+" "+doc+" "+"1")
                o.write("\n")

# %%
getQrels(qrels)

# %%
def get_trec_eval(query_map,name):
    
    filename = name +".txt"
    with open(filename,"w") as o:
        for qno in query_map:
            for doc in query_map[qno]:
                o.write(str(int(qno))+" "+"Q0"+" "+doc+" "+"1"+" "+ str(query_map[qno][doc]) +" "+"runidl")
                o.write("\n")

# %%
get_trec_eval(get_query_map("ap","kmeans"),"Trec_AP_Bert_Kmeans")
get_trec_eval(get_query_map("ap","clarans"),"Trec_AP_Bert_Clarans")
get_trec_eval(get_query_map("zf","kmeans"),"Trec_ZF_Bert_Kmeans")
get_trec_eval(get_query_map("zf","clarans"),"Trec_ZF_Bert_Clarans")

# %%
evaluator = pytrec_eval.RelevanceEvaluator(
    qrels, pytrec_eval.supported_measures)

# %%
def get_all_rankings(dataset,cluster):
    if (dataset == "ap"):
        if (cluster == "kmeans"):
            query_map = get_query_map("ap","kmeans")
            return(json.dumps(evaluator.evaluate(query_map), indent=1))
        else:
            query_map = get_query_map("ap","clarans")
            return(json.dumps(evaluator.evaluate(query_map), indent=1))
    else:
        if (cluster == "kmeans"):
            query_map = get_query_map("zf","kmeans")
            return(json.dumps(evaluator.evaluate(query_map), indent=1))
        else:
            query_map = get_query_map("zf","clarans")
            return(json.dumps(evaluator.evaluate(query_map), indent=1))

# %%
print(get_all_rankings("ap","kmeans"))
# Out:
# {
#  "51": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 137.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "52": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 533.0,
#   "num_rel_ret": 1.0,
#   "map": 1.9144618447754334e-05,
#   "gm_map": -10.863488902836417,
#   "Rprec": 0.001876172607879925,
#   "bpref": 0.001876172607879925,
#   "recip_rank": 0.01020408163265306,
#   "iprec_at_recall_0.00": 0.01020408163265306,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.001876172607879925,
#   "recall_200": 0.001876172607879925,
#   "recall_500": 0.001876172607879925,
#   "recall_1000": 0.001876172607879925,
#   "infAP": 1.9144618447754334e-05,
#   "gm_bpref": -6.278521424165844,
#   "Rprec_mult_0.20": 0.009345794392523364,
#   "Rprec_mult_0.40": 0.004672897196261682,
#   "Rprec_mult_0.60": 0.003125,
#   "Rprec_mult_0.80": 0.00234192037470726,
#   "Rprec_mult_1.00": 0.001876172607879925,
#   "Rprec_mult_1.20": 0.0015625,
#   "Rprec_mult_1.40": 0.0013386880856760374,
#   "Rprec_mult_1.60": 0.0011723329425556857,
#   "Rprec_mult_1.80": 0.0010416666666666667,
#   "Rprec_mult_2.00": 0.0009380863039399625,
#   "utility": -97.0,
#   "11pt_avg": 0.0009276437847866418,
#   "binG": 0.0002830097572662179,
#   "G": 0.0002830097572662179,
#   "ndcg": 0.002032481569200967,
#   "ndcg_rel": 0.0020423813477784937,
#   "Rndcg": 0.002032481569200967,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.007204096264208284,
#   "ndcg_cut_200": 0.004332354542617791,
#   "ndcg_cut_500": 0.00213791160384796,
#   "ndcg_cut_1000": 0.002032481569200967,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 1.9144618447754334e-05,
#   "map_cut_200": 1.9144618447754334e-05,
#   "map_cut_500": 1.9144618447754334e-05,
#   "map_cut_1000": 1.9144618447754334e-05,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.01,
#   "relative_P_200": 0.005,
#   "relative_P_500": 0.002,
#   "relative_P_1000": 0.001876172607879925,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.010101010101010102,
#   "set_recall": 0.001876172607879925,
#   "set_map": 1.8951238463433585e-05,
#   "set_F": 0.0031645569620253164,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "53": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 571.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "54": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 171.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "55": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 810.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "56": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 877.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "57": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 461.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "58": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 159.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "59": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 579.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "60": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 60.0,
#   "num_rel_ret": 1.0,
#   "map": 0.00042735042735042735,
#   "gm_map": -7.757906208351747,
#   "Rprec": 0.016666666666666666,
#   "bpref": 0.016666666666666666,
#   "recip_rank": 0.02564102564102564,
#   "iprec_at_recall_0.00": 0.02564102564102564,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.016666666666666666,
#   "recall_200": 0.016666666666666666,
#   "recall_500": 0.016666666666666666,
#   "recall_1000": 0.016666666666666666,
#   "infAP": 0.00042735042735042735,
#   "gm_bpref": -4.0943445622221,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.020833333333333332,
#   "Rprec_mult_1.00": 0.016666666666666666,
#   "Rprec_mult_1.20": 0.013888888888888888,
#   "Rprec_mult_1.40": 0.011904761904761904,
#   "Rprec_mult_1.60": 0.010416666666666666,
#   "Rprec_mult_1.80": 0.009259259259259259,
#   "Rprec_mult_2.00": 0.008333333333333333,
#   "utility": -97.0,
#   "11pt_avg": 0.002331002331002331,
#   "binG": 0.003131697078485126,
#   "G": 0.003131697078485126,
#   "ndcg": 0.012855266894581779,
#   "ndcg_rel": 0.012928208692089382,
#   "Rndcg": 0.012855266894581779,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.012855266894581779,
#   "ndcg_cut_200": 0.012855266894581779,
#   "ndcg_cut_500": 0.012855266894581779,
#   "ndcg_cut_1000": 0.012855266894581779,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.00042735042735042735,
#   "map_cut_200": 0.00042735042735042735,
#   "map_cut_500": 0.00042735042735042735,
#   "map_cut_1000": 0.00042735042735042735,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.016666666666666666,
#   "relative_P_200": 0.016666666666666666,
#   "relative_P_500": 0.016666666666666666,
#   "relative_P_1000": 0.016666666666666666,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.016666666666666666,
#   "set_recall": 0.016666666666666666,
#   "set_map": 0.00016835016835016836,
#   "set_F": 0.012578616352201259,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "61": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 206.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "62": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 297.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "63": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 198.0,
#   "num_rel_ret": 3.0,
#   "map": 0.005100019805902158,
#   "gm_map": -5.278510855749171,
#   "Rprec": 0.015151515151515152,
#   "bpref": 0.015151515151515152,
#   "recip_rank": 0.5,
#   "iprec_at_recall_0.00": 0.5,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.2,
#   "P_10": 0.2,
#   "P_15": 0.13333333333333333,
#   "P_20": 0.15,
#   "P_30": 0.1,
#   "P_100": 0.03,
#   "P_200": 0.015,
#   "P_500": 0.006,
#   "P_1000": 0.003,
#   "relstring": 0.0,
#   "recall_5": 0.005050505050505051,
#   "recall_10": 0.010101010101010102,
#   "recall_15": 0.010101010101010102,
#   "recall_20": 0.015151515151515152,
#   "recall_30": 0.015151515151515152,
#   "recall_100": 0.015151515151515152,
#   "recall_200": 0.015151515151515152,
#   "recall_500": 0.015151515151515152,
#   "recall_1000": 0.015151515151515152,
#   "infAP": 0.005100008417706472,
#   "gm_bpref": -4.189654742026425,
#   "Rprec_mult_0.20": 0.075,
#   "Rprec_mult_0.40": 0.0375,
#   "Rprec_mult_0.60": 0.025210084033613446,
#   "Rprec_mult_0.80": 0.018867924528301886,
#   "Rprec_mult_1.00": 0.015151515151515152,
#   "Rprec_mult_1.20": 0.012605042016806723,
#   "Rprec_mult_1.40": 0.01079136690647482,
#   "Rprec_mult_1.60": 0.00946372239747634,
#   "Rprec_mult_1.80": 0.008403361344537815,
#   "Rprec_mult_2.00": 0.007575757575757576,
#   "utility": -93.0,
#   "11pt_avg": 0.045454545454545456,
#   "binG": 0.006402942226292925,
#   "G": 0.006402942226292925,
#   "ndcg": 0.035505563326835465,
#   "ndcg_rel": 0.03940654345604168,
#   "Rndcg": 0.035505563326835465,
#   "ndcg_cut_5": 0.21398626473452756,
#   "ndcg_cut_10": 0.21726071285222986,
#   "ndcg_cut_15": 0.16841466178325942,
#   "ndcg_cut_20": 0.174275942433943,
#   "ndcg_cut_30": 0.1339233262953349,
#   "ndcg_cut_100": 0.058597291805884306,
#   "ndcg_cut_200": 0.035505563326835465,
#   "ndcg_cut_500": 0.035505563326835465,
#   "ndcg_cut_1000": 0.035505563326835465,
#   "map_cut_5": 0.0025252525252525255,
#   "map_cut_10": 0.004208754208754209,
#   "map_cut_15": 0.004208754208754209,
#   "map_cut_20": 0.005100019805902158,
#   "map_cut_30": 0.005100019805902158,
#   "map_cut_100": 0.005100019805902158,
#   "map_cut_200": 0.005100019805902158,
#   "map_cut_500": 0.005100019805902158,
#   "map_cut_1000": 0.005100019805902158,
#   "relative_P_5": 0.2,
#   "relative_P_10": 0.2,
#   "relative_P_15": 0.13333333333333333,
#   "relative_P_20": 0.15,
#   "relative_P_30": 0.1,
#   "relative_P_100": 0.03,
#   "relative_P_200": 0.015151515151515152,
#   "relative_P_500": 0.015151515151515152,
#   "relative_P_1000": 0.015151515151515152,
#   "success_1": 0.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.030303030303030304,
#   "set_relative_P": 0.030303030303030304,
#   "set_recall": 0.015151515151515152,
#   "set_map": 0.0004591368227731864,
#   "set_F": 0.020202020202020204,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "64": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 374.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "65": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 318.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "66": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 164.0,
#   "num_rel_ret": 1.0,
#   "map": 0.00023452157598499062,
#   "gm_map": -8.357962965845681,
#   "Rprec": 0.006097560975609756,
#   "bpref": 0.006097560975609756,
#   "recip_rank": 0.038461538461538464,
#   "iprec_at_recall_0.00": 0.038461538461538464,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.03333333333333333,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.006097560975609756,
#   "recall_100": 0.006097560975609756,
#   "recall_200": 0.006097560975609756,
#   "recall_500": 0.006097560975609756,
#   "recall_1000": 0.006097560975609756,
#   "infAP": 0.00023452157598499062,
#   "gm_bpref": -5.099866427824199,
#   "Rprec_mult_0.20": 0.030303030303030304,
#   "Rprec_mult_0.40": 0.015151515151515152,
#   "Rprec_mult_0.60": 0.010101010101010102,
#   "Rprec_mult_0.80": 0.007575757575757576,
#   "Rprec_mult_1.00": 0.006097560975609756,
#   "Rprec_mult_1.20": 0.005076142131979695,
#   "Rprec_mult_1.40": 0.004347826086956522,
#   "Rprec_mult_1.60": 0.0038022813688212928,
#   "Rprec_mult_1.80": 0.0033783783783783786,
#   "Rprec_mult_2.00": 0.003048780487804878,
#   "utility": -97.0,
#   "11pt_avg": 0.0034965034965034965,
#   "binG": 0.0012823775479094664,
#   "G": 0.0012823775479094664,
#   "ndcg": 0.007003664490116153,
#   "ndcg_rel": 0.007114683259247511,
#   "Rndcg": 0.007003664490116153,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.022955635811839507,
#   "ndcg_cut_100": 0.010044091103961955,
#   "ndcg_cut_200": 0.007003664490116153,
#   "ndcg_cut_500": 0.007003664490116153,
#   "ndcg_cut_1000": 0.007003664490116153,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.00023452157598499062,
#   "map_cut_100": 0.00023452157598499062,
#   "map_cut_200": 0.00023452157598499062,
#   "map_cut_500": 0.00023452157598499062,
#   "map_cut_1000": 0.00023452157598499062,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.03333333333333333,
#   "relative_P_100": 0.01,
#   "relative_P_200": 0.006097560975609756,
#   "relative_P_500": 0.006097560975609756,
#   "relative_P_1000": 0.006097560975609756,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.010101010101010102,
#   "set_recall": 0.006097560975609756,
#   "set_map": 6.159152500615915e-05,
#   "set_F": 0.007604562737642586,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "67": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 534.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "68": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 96.0,
#   "num_rel_ret": 3.0,
#   "map": 0.010518790849673202,
#   "gm_map": -4.554592016522472,
#   "Rprec": 0.03125,
#   "bpref": 0.03125,
#   "recip_rank": 0.3333333333333333,
#   "iprec_at_recall_0.00": 0.5,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.4,
#   "P_10": 0.2,
#   "P_15": 0.13333333333333333,
#   "P_20": 0.15,
#   "P_30": 0.1,
#   "P_100": 0.03,
#   "P_200": 0.015,
#   "P_500": 0.006,
#   "P_1000": 0.003,
#   "relstring": 0.0,
#   "recall_5": 0.020833333333333332,
#   "recall_10": 0.020833333333333332,
#   "recall_15": 0.020833333333333332,
#   "recall_20": 0.03125,
#   "recall_30": 0.03125,
#   "recall_100": 0.03125,
#   "recall_200": 0.03125,
#   "recall_500": 0.03125,
#   "recall_1000": 0.03125,
#   "infAP": 0.010518758681137651,
#   "gm_bpref": -3.4657359027997265,
#   "Rprec_mult_0.20": 0.15,
#   "Rprec_mult_0.40": 0.07692307692307693,
#   "Rprec_mult_0.60": 0.05172413793103448,
#   "Rprec_mult_0.80": 0.03896103896103896,
#   "Rprec_mult_1.00": 0.03125,
#   "Rprec_mult_1.20": 0.02586206896551724,
#   "Rprec_mult_1.40": 0.022222222222222223,
#   "Rprec_mult_1.60": 0.01948051948051948,
#   "Rprec_mult_1.80": 0.017341040462427744,
#   "Rprec_mult_2.00": 0.015625,
#   "utility": -93.0,
#   "11pt_avg": 0.045454545454545456,
#   "binG": 0.013020833333333334,
#   "G": 0.013020833333333334,
#   "ndcg": 0.05755764685689504,
#   "ndcg_rel": 0.0639090493893144,
#   "Rndcg": 0.05755764685689504,
#   "ndcg_cut_5": 0.3156484524795145,
#   "ndcg_cut_10": 0.20483424751859086,
#   "ndcg_cut_15": 0.15878200004312407,
#   "ndcg_cut_20": 0.16625630745084302,
#   "ndcg_cut_30": 0.12776059277278762,
#   "ndcg_cut_100": 0.05755764685689504,
#   "ndcg_cut_200": 0.05755764685689504,
#   "ndcg_cut_500": 0.05755764685689504,
#   "ndcg_cut_1000": 0.05755764685689504,
#   "map_cut_5": 0.008680555555555554,
#   "map_cut_10": 0.008680555555555554,
#   "map_cut_15": 0.008680555555555554,
#   "map_cut_20": 0.010518790849673202,
#   "map_cut_30": 0.010518790849673202,
#   "map_cut_100": 0.010518790849673202,
#   "map_cut_200": 0.010518790849673202,
#   "map_cut_500": 0.010518790849673202,
#   "map_cut_1000": 0.010518790849673202,
#   "relative_P_5": 0.4,
#   "relative_P_10": 0.2,
#   "relative_P_15": 0.13333333333333333,
#   "relative_P_20": 0.15,
#   "relative_P_30": 0.1,
#   "relative_P_100": 0.03125,
#   "relative_P_200": 0.03125,
#   "relative_P_500": 0.03125,
#   "relative_P_1000": 0.03125,
#   "success_1": 0.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.030303030303030304,
#   "set_relative_P": 0.03125,
#   "set_recall": 0.03125,
#   "set_map": 0.000946969696969697,
#   "set_F": 0.03076923076923077,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "69": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 47.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "70": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 55.0,
#   "num_rel_ret": 1.0,
#   "map": 0.01818181818181818,
#   "gm_map": -4.007333185232471,
#   "Rprec": 0.01818181818181818,
#   "bpref": 0.01818181818181818,
#   "recip_rank": 1.0,
#   "iprec_at_recall_0.00": 1.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.2,
#   "P_10": 0.1,
#   "P_15": 0.06666666666666667,
#   "P_20": 0.05,
#   "P_30": 0.03333333333333333,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.01818181818181818,
#   "recall_10": 0.01818181818181818,
#   "recall_15": 0.01818181818181818,
#   "recall_20": 0.01818181818181818,
#   "recall_30": 0.01818181818181818,
#   "recall_100": 0.01818181818181818,
#   "recall_200": 0.01818181818181818,
#   "recall_500": 0.01818181818181818,
#   "recall_1000": 0.01818181818181818,
#   "infAP": 0.01818181818181818,
#   "gm_bpref": -4.007333185232471,
#   "Rprec_mult_0.20": 0.09090909090909091,
#   "Rprec_mult_0.40": 0.045454545454545456,
#   "Rprec_mult_0.60": 0.030303030303030304,
#   "Rprec_mult_0.80": 0.022727272727272728,
#   "Rprec_mult_1.00": 0.01818181818181818,
#   "Rprec_mult_1.20": 0.015151515151515152,
#   "Rprec_mult_1.40": 0.012987012987012988,
#   "Rprec_mult_1.60": 0.011363636363636364,
#   "Rprec_mult_1.80": 0.010101010101010102,
#   "Rprec_mult_2.00": 0.00909090909090909,
#   "utility": -97.0,
#   "11pt_avg": 0.09090909090909091,
#   "binG": 0.01818181818181818,
#   "G": 0.01818181818181818,
#   "ndcg": 0.0726391988207375,
#   "ndcg_rel": 0.08950030429672408,
#   "Rndcg": 0.0726391988207375,
#   "ndcg_cut_5": 0.3391602052736161,
#   "ndcg_cut_10": 0.22009176629808017,
#   "ndcg_cut_15": 0.17060921827860473,
#   "ndcg_cut_20": 0.1420400396336573,
#   "ndcg_cut_30": 0.1091514658259318,
#   "ndcg_cut_100": 0.0726391988207375,
#   "ndcg_cut_200": 0.0726391988207375,
#   "ndcg_cut_500": 0.0726391988207375,
#   "ndcg_cut_1000": 0.0726391988207375,
#   "map_cut_5": 0.01818181818181818,
#   "map_cut_10": 0.01818181818181818,
#   "map_cut_15": 0.01818181818181818,
#   "map_cut_20": 0.01818181818181818,
#   "map_cut_30": 0.01818181818181818,
#   "map_cut_100": 0.01818181818181818,
#   "map_cut_200": 0.01818181818181818,
#   "map_cut_500": 0.01818181818181818,
#   "map_cut_1000": 0.01818181818181818,
#   "relative_P_5": 0.2,
#   "relative_P_10": 0.1,
#   "relative_P_15": 0.06666666666666667,
#   "relative_P_20": 0.05,
#   "relative_P_30": 0.03333333333333333,
#   "relative_P_100": 0.01818181818181818,
#   "relative_P_200": 0.01818181818181818,
#   "relative_P_500": 0.01818181818181818,
#   "relative_P_1000": 0.01818181818181818,
#   "success_1": 1.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.01818181818181818,
#   "set_recall": 0.01818181818181818,
#   "set_map": 0.00018365472910927456,
#   "set_F": 0.012987012987012988,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "71": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 380.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
# ...
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.2,
#   "P_10": 0.2,
#   "P_15": 0.13333333333333333,
#   "P_20": 0.1,
#   "P_30": 0.06666666666666667,
#   "P_100": 0.03,
#   "P_200": 0.015,
#   "P_500": 0.006,
#   "P_1000": 0.003,
#   "relstring": 0.0,
#   "recall_5": 0.005,
#   "recall_10": 0.01,
#   "recall_15": 0.01,
#   "recall_20": 0.01,
#   "recall_30": 0.01,
#   "recall_100": 0.015,
#   "recall_200": 0.015,
#   "recall_500": 0.015,
#   "recall_1000": 0.015,
#   "infAP": 0.004412433640711979,
#   "gm_bpref": -4.199705077879927,
#   "Rprec_mult_0.20": 0.075,
#   "Rprec_mult_0.40": 0.0375,
#   "Rprec_mult_0.60": 0.025,
#   "Rprec_mult_0.80": 0.01875,
#   "Rprec_mult_1.00": 0.015,
#   "Rprec_mult_1.20": 0.0125,
#   "Rprec_mult_1.40": 0.010714285714285714,
#   "Rprec_mult_1.60": 0.009375,
#   "Rprec_mult_1.80": 0.008333333333333333,
#   "Rprec_mult_2.00": 0.0075,
#   "utility": -93.0,
#   "11pt_avg": 0.045454545454545456,
#   "binG": 0.0059546599388499285,
#   "G": 0.0059546599388499285,
#   "ndcg": 0.03343847792971523,
#   "ndcg_rel": 0.03681826067677108,
#   "Rndcg": 0.03343847792971523,
#   "ndcg_cut_5": 0.21398626473452756,
#   "ndcg_cut_10": 0.21222636597291458,
#   "ndcg_cut_15": 0.16451217147174066,
#   "ndcg_cut_20": 0.13696396708122924,
#   "ndcg_cut_30": 0.10525072937749579,
#   "ndcg_cut_100": 0.05560348571765651,
#   "ndcg_cut_200": 0.03343847792971523,
#   "ndcg_cut_500": 0.03343847792971523,
#   "ndcg_cut_1000": 0.03343847792971523,
#   "map_cut_5": 0.0025,
#   "map_cut_10": 0.003928571428571429,
#   "map_cut_15": 0.003928571428571429,
#   "map_cut_20": 0.003928571428571429,
#   "map_cut_30": 0.003928571428571429,
#   "map_cut_100": 0.004412442396313364,
#   "map_cut_200": 0.004412442396313364,
#   "map_cut_500": 0.004412442396313364,
#   "map_cut_1000": 0.004412442396313364,
#   "relative_P_5": 0.2,
#   "relative_P_10": 0.2,
#   "relative_P_15": 0.13333333333333333,
#   "relative_P_20": 0.1,
#   "relative_P_30": 0.06666666666666667,
#   "relative_P_100": 0.03,
#   "relative_P_200": 0.015,
#   "relative_P_500": 0.015,
#   "relative_P_1000": 0.015,
#   "success_1": 0.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.030303030303030304,
#   "set_relative_P": 0.030303030303030304,
#   "set_recall": 0.015,
#   "set_map": 0.00045454545454545455,
#   "set_F": 0.020066889632107024,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "96": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 190.0,
#   "num_rel_ret": 7.0,
#   "map": 0.024415204678362574,
#   "gm_map": -3.712549198199841,
#   "Rprec": 0.03684210526315789,
#   "bpref": 0.03684210526315789,
#   "recip_rank": 1.0,
#   "iprec_at_recall_0.00": 1.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.6,
#   "P_10": 0.5,
#   "P_15": 0.4,
#   "P_20": 0.35,
#   "P_30": 0.23333333333333334,
#   "P_100": 0.07,
#   "P_200": 0.035,
#   "P_500": 0.014,
#   "P_1000": 0.007,
#   "relstring": 0.0,
#   "recall_5": 0.015789473684210527,
#   "recall_10": 0.02631578947368421,
#   "recall_15": 0.031578947368421054,
#   "recall_20": 0.03684210526315789,
#   "recall_30": 0.03684210526315789,
#   "recall_100": 0.03684210526315789,
#   "recall_200": 0.03684210526315789,
#   "recall_500": 0.03684210526315789,
#   "recall_1000": 0.03684210526315789,
#   "infAP": 0.024415145740107475,
#   "gm_bpref": -3.301113923105173,
#   "Rprec_mult_0.20": 0.18421052631578946,
#   "Rprec_mult_0.40": 0.09210526315789473,
#   "Rprec_mult_0.60": 0.06140350877192982,
#   "Rprec_mult_0.80": 0.046052631578947366,
#   "Rprec_mult_1.00": 0.03684210526315789,
#   "Rprec_mult_1.20": 0.03070175438596491,
#   "Rprec_mult_1.40": 0.02631578947368421,
#   "Rprec_mult_1.60": 0.023026315789473683,
#   "Rprec_mult_1.80": 0.02046783625730994,
#   "Rprec_mult_2.00": 0.018421052631578946,
#   "utility": -85.0,
#   "11pt_avg": 0.09090909090909091,
#   "binG": 0.020995166572864075,
#   "G": 0.020995166572864075,
#   "ndcg": 0.09477189005665466,
#   "ndcg_rel": 0.11791329868060724,
#   "Rndcg": 0.09477189005665466,
#   "ndcg_cut_5": 0.6992148198508501,
#   "ndcg_cut_10": 0.5907272848394973,
#   "ndcg_cut_15": 0.501584703229041,
#   "ndcg_cut_20": 0.4510298808530599,
#   "ndcg_cut_30": 0.34659644388568134,
#   "ndcg_cut_100": 0.15165104932103635,
#   "ndcg_cut_200": 0.09477189005665466,
#   "ndcg_cut_500": 0.09477189005665466,
#   "ndcg_cut_1000": 0.09477189005665466,
#   "map_cut_5": 0.014473684210526316,
#   "map_cut_10": 0.020112781954887218,
#   "map_cut_15": 0.02236842105263158,
#   "map_cut_20": 0.024415204678362574,
#   "map_cut_30": 0.024415204678362574,
#   "map_cut_100": 0.024415204678362574,
#   "map_cut_200": 0.024415204678362574,
#   "map_cut_500": 0.024415204678362574,
#   "map_cut_1000": 0.024415204678362574,
#   "relative_P_5": 0.6,
#   "relative_P_10": 0.5,
#   "relative_P_15": 0.4,
#   "relative_P_20": 0.35,
#   "relative_P_30": 0.23333333333333334,
#   "relative_P_100": 0.07,
#   "relative_P_200": 0.03684210526315789,
#   "relative_P_500": 0.03684210526315789,
#   "relative_P_1000": 0.03684210526315789,
#   "success_1": 1.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.0707070707070707,
#   "set_relative_P": 0.0707070707070707,
#   "set_recall": 0.03684210526315789,
#   "set_map": 0.002604997341839447,
#   "set_F": 0.04844290657439446,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "97": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 336.0,
#   "num_rel_ret": 1.0,
#   "map": 0.002976190476190476,
#   "gm_map": -5.817111159963204,
#   "Rprec": 0.002976190476190476,
#   "bpref": 0.002976190476190476,
#   "recip_rank": 1.0,
#   "iprec_at_recall_0.00": 1.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.2,
#   "P_10": 0.1,
#   "P_15": 0.06666666666666667,
#   "P_20": 0.05,
#   "P_30": 0.03333333333333333,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.002976190476190476,
#   "recall_10": 0.002976190476190476,
#   "recall_15": 0.002976190476190476,
#   "recall_20": 0.002976190476190476,
#   "recall_30": 0.002976190476190476,
#   "recall_100": 0.002976190476190476,
#   "recall_200": 0.002976190476190476,
#   "recall_500": 0.002976190476190476,
#   "recall_1000": 0.002976190476190476,
#   "infAP": 0.002976190476190476,
#   "gm_bpref": -5.817111159963204,
#   "Rprec_mult_0.20": 0.014705882352941176,
#   "Rprec_mult_0.40": 0.007407407407407408,
#   "Rprec_mult_0.60": 0.0049504950495049506,
#   "Rprec_mult_0.80": 0.0037174721189591076,
#   "Rprec_mult_1.00": 0.002976190476190476,
#   "Rprec_mult_1.20": 0.0024752475247524753,
#   "Rprec_mult_1.40": 0.0021231422505307855,
#   "Rprec_mult_1.60": 0.0018587360594795538,
#   "Rprec_mult_1.80": 0.001652892561983471,
#   "Rprec_mult_2.00": 0.001488095238095238,
#   "utility": -97.0,
#   "11pt_avg": 0.09090909090909091,
#   "binG": 0.002976190476190476,
#   "G": 0.002976190476190476,
#   "ndcg": 0.01933993183616989,
#   "ndcg_rel": 0.02225856299141939,
#   "Rndcg": 0.01933993183616989,
#   "ndcg_cut_5": 0.3391602052736161,
#   "ndcg_cut_10": 0.22009176629808017,
#   "ndcg_cut_15": 0.17060921827860473,
#   "ndcg_cut_20": 0.1420400396336573,
#   "ndcg_cut_30": 0.1091514658259318,
#   "ndcg_cut_100": 0.047758523260819974,
#   "ndcg_cut_200": 0.02872072326763522,
#   "ndcg_cut_500": 0.01933993183616989,
#   "ndcg_cut_1000": 0.01933993183616989,
#   "map_cut_5": 0.002976190476190476,
#   "map_cut_10": 0.002976190476190476,
#   "map_cut_15": 0.002976190476190476,
#   "map_cut_20": 0.002976190476190476,
#   "map_cut_30": 0.002976190476190476,
#   "map_cut_100": 0.002976190476190476,
#   "map_cut_200": 0.002976190476190476,
#   "map_cut_500": 0.002976190476190476,
#   "map_cut_1000": 0.002976190476190476,
#   "relative_P_5": 0.2,
#   "relative_P_10": 0.1,
#   "relative_P_15": 0.06666666666666667,
#   "relative_P_20": 0.05,
#   "relative_P_30": 0.03333333333333333,
#   "relative_P_100": 0.01,
#   "relative_P_200": 0.005,
#   "relative_P_500": 0.002976190476190476,
#   "relative_P_1000": 0.002976190476190476,
#   "success_1": 1.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.010101010101010102,
#   "set_recall": 0.002976190476190476,
#   "set_map": 3.0062530062530064e-05,
#   "set_F": 0.004597701149425287,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "98": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 662.0,
#   "num_rel_ret": 1.0,
#   "map": 0.0015105740181268882,
#   "gm_map": -6.495265555937008,
#   "Rprec": 0.0015105740181268882,
#   "bpref": 0.0015105740181268882,
#   "recip_rank": 1.0,
#   "iprec_at_recall_0.00": 1.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.2,
#   "P_10": 0.1,
#   "P_15": 0.06666666666666667,
#   "P_20": 0.05,
#   "P_30": 0.03333333333333333,
#   "P_100": 0.01,
#   "P_200": 0.005,
#   "P_500": 0.002,
#   "P_1000": 0.001,
#   "relstring": 0.0,
#   "recall_5": 0.0015105740181268882,
#   "recall_10": 0.0015105740181268882,
#   "recall_15": 0.0015105740181268882,
#   "recall_20": 0.0015105740181268882,
#   "recall_30": 0.0015105740181268882,
#   "recall_100": 0.0015105740181268882,
#   "recall_200": 0.0015105740181268882,
#   "recall_500": 0.0015105740181268882,
#   "recall_1000": 0.0015105740181268882,
#   "infAP": 0.0015105740181268882,
#   "gm_bpref": -6.495265555937008,
#   "Rprec_mult_0.20": 0.007518796992481203,
#   "Rprec_mult_0.40": 0.0037735849056603774,
#   "Rprec_mult_0.60": 0.002512562814070352,
#   "Rprec_mult_0.80": 0.0018867924528301887,
#   "Rprec_mult_1.00": 0.0015105740181268882,
#   "Rprec_mult_1.20": 0.0012578616352201257,
#   "Rprec_mult_1.40": 0.0010787486515641855,
#   "Rprec_mult_1.60": 0.0009433962264150943,
#   "Rprec_mult_1.80": 0.0008389261744966443,
#   "Rprec_mult_2.00": 0.0007552870090634441,
#   "utility": -97.0,
#   "11pt_avg": 0.09090909090909091,
#   "binG": 0.0015105740181268882,
#   "G": 0.0015105740181268882,
#   "ndcg": 0.011337362951741365,
#   "ndcg_rel": 0.012830811043959278,
#   "Rndcg": 0.011337362951741365,
#   "ndcg_cut_5": 0.3391602052736161,
#   "ndcg_cut_10": 0.22009176629808017,
#   "ndcg_cut_15": 0.17060921827860473,
#   "ndcg_cut_20": 0.1420400396336573,
#   "ndcg_cut_30": 0.1091514658259318,
#   "ndcg_cut_100": 0.047758523260819974,
#   "ndcg_cut_200": 0.02872072326763522,
#   "ndcg_cut_500": 0.01417297844411449,
#   "ndcg_cut_1000": 0.011337362951741365,
#   "map_cut_5": 0.0015105740181268882,
#   "map_cut_10": 0.0015105740181268882,
#   "map_cut_15": 0.0015105740181268882,
#   "map_cut_20": 0.0015105740181268882,
#   "map_cut_30": 0.0015105740181268882,
#   "map_cut_100": 0.0015105740181268882,
#   "map_cut_200": 0.0015105740181268882,
#   "map_cut_500": 0.0015105740181268882,
#   "map_cut_1000": 0.0015105740181268882,
#   "relative_P_5": 0.2,
#   "relative_P_10": 0.1,
#   "relative_P_15": 0.06666666666666667,
#   "relative_P_20": 0.05,
#   "relative_P_30": 0.03333333333333333,
#   "relative_P_100": 0.01,
#   "relative_P_200": 0.005,
#   "relative_P_500": 0.002,
#   "relative_P_1000": 0.0015105740181268882,
#   "success_1": 1.0,
#   "success_5": 1.0,
#   "success_10": 1.0,
#   "set_P": 0.010101010101010102,
#   "set_relative_P": 0.010101010101010102,
#   "set_recall": 0.0015105740181268882,
#   "set_map": 1.5258323415423113e-05,
#   "set_F": 0.002628120893561104,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "99": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 288.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  },
#  "100": {
#   "runid": 0.0,
#   "num_q": 1.0,
#   "num_ret": 99.0,
#   "num_rel": 249.0,
#   "num_rel_ret": 0.0,
#   "map": 0.0,
#   "gm_map": -11.512925464970229,
#   "Rprec": 0.0,
#   "bpref": 0.0,
#   "recip_rank": 0.0,
#   "iprec_at_recall_0.00": 0.0,
#   "iprec_at_recall_0.10": 0.0,
#   "iprec_at_recall_0.20": 0.0,
#   "iprec_at_recall_0.30": 0.0,
#   "iprec_at_recall_0.40": 0.0,
#   "iprec_at_recall_0.50": 0.0,
#   "iprec_at_recall_0.60": 0.0,
#   "iprec_at_recall_0.70": 0.0,
#   "iprec_at_recall_0.80": 0.0,
#   "iprec_at_recall_0.90": 0.0,
#   "iprec_at_recall_1.00": 0.0,
#   "P_5": 0.0,
#   "P_10": 0.0,
#   "P_15": 0.0,
#   "P_20": 0.0,
#   "P_30": 0.0,
#   "P_100": 0.0,
#   "P_200": 0.0,
#   "P_500": 0.0,
#   "P_1000": 0.0,
#   "relstring": 0.0,
#   "recall_5": 0.0,
#   "recall_10": 0.0,
#   "recall_15": 0.0,
#   "recall_20": 0.0,
#   "recall_30": 0.0,
#   "recall_100": 0.0,
#   "recall_200": 0.0,
#   "recall_500": 0.0,
#   "recall_1000": 0.0,
#   "infAP": 0.0,
#   "gm_bpref": -11.512925464970229,
#   "Rprec_mult_0.20": 0.0,
#   "Rprec_mult_0.40": 0.0,
#   "Rprec_mult_0.60": 0.0,
#   "Rprec_mult_0.80": 0.0,
#   "Rprec_mult_1.00": 0.0,
#   "Rprec_mult_1.20": 0.0,
#   "Rprec_mult_1.40": 0.0,
#   "Rprec_mult_1.60": 0.0,
#   "Rprec_mult_1.80": 0.0,
#   "Rprec_mult_2.00": 0.0,
#   "utility": -99.0,
#   "11pt_avg": 0.0,
#   "binG": 0.0,
#   "G": 0.0,
#   "ndcg": 0.0,
#   "ndcg_rel": 0.0,
#   "Rndcg": 0.0,
#   "ndcg_cut_5": 0.0,
#   "ndcg_cut_10": 0.0,
#   "ndcg_cut_15": 0.0,
#   "ndcg_cut_20": 0.0,
#   "ndcg_cut_30": 0.0,
#   "ndcg_cut_100": 0.0,
#   "ndcg_cut_200": 0.0,
#   "ndcg_cut_500": 0.0,
#   "ndcg_cut_1000": 0.0,
#   "map_cut_5": 0.0,
#   "map_cut_10": 0.0,
#   "map_cut_15": 0.0,
#   "map_cut_20": 0.0,
#   "map_cut_30": 0.0,
#   "map_cut_100": 0.0,
#   "map_cut_200": 0.0,
#   "map_cut_500": 0.0,
#   "map_cut_1000": 0.0,
#   "relative_P_5": 0.0,
#   "relative_P_10": 0.0,
#   "relative_P_15": 0.0,
#   "relative_P_20": 0.0,
#   "relative_P_30": 0.0,
#   "relative_P_100": 0.0,
#   "relative_P_200": 0.0,
#   "relative_P_500": 0.0,
#   "relative_P_1000": 0.0,
#   "success_1": 0.0,
#   "success_5": 0.0,
#   "success_10": 0.0,
#   "set_P": 0.0,
#   "set_relative_P": 0.0,
#   "set_recall": 0.0,
#   "set_map": 0.0,
#   "set_F": 0.0,
#   "num_nonrel_judged_ret": 0.0
#  }
# }

# %%
get_all_rankings("ap","clarans")
# Out:
# '{\n "51": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 99.0,\n  "num_rel": 137.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -99.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": 0.0,\n  "relative_P_5": 0.0,\n  "relative_P_10": 0.0,\n  "relative_P_15": 0.0,\n  "relative_P_20": 0.0,\n  "relative_P_30": 0.0,\n  "relative_P_100": 0.0,\n  "relative_P_200": 0.0,\n  "relative_P_500": 0.0,\n  "relative_P_1000": 0.0,\n  "success_1": 0.0,\n  "success_5": 0.0,\n  "success_10": 0.0,\n  "set_P": 0.0,\n  "set_relative_P": 0.0,\n  "set_recall": 0.0,\n  "set_map": 0.0,\n  "set_F": 0.0,\n  "num_nonrel_judged_ret": 0.0\n },\n "52": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 99.0,\n  "num_rel": 533.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -99.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": ...

# %%
get_all_rankings("zf","kmeans")
# Out:
# '{\n "51": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 99.0,\n  "num_rel": 137.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -99.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": 0.0,\n  "relative_P_5": 0.0,\n  "relative_P_10": 0.0,\n  "relative_P_15": 0.0,\n  "relative_P_20": 0.0,\n  "relative_P_30": 0.0,\n  "relative_P_100": 0.0,\n  "relative_P_200": 0.0,\n  "relative_P_500": 0.0,\n  "relative_P_1000": 0.0,\n  "success_1": 0.0,\n  "success_5": 0.0,\n  "success_10": 0.0,\n  "set_P": 0.0,\n  "set_relative_P": 0.0,\n  "set_recall": 0.0,\n  "set_map": 0.0,\n  "set_F": 0.0,\n  "num_nonrel_judged_ret": 0.0\n },\n "52": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 99.0,\n  "num_rel": 533.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -99.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": ...

# %%
get_all_rankings("zf","clarans")
# Out:
# '{\n "51": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 12.0,\n  "num_rel": 137.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -12.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": 0.0,\n  "relative_P_5": 0.0,\n  "relative_P_10": 0.0,\n  "relative_P_15": 0.0,\n  "relative_P_20": 0.0,\n  "relative_P_30": 0.0,\n  "relative_P_100": 0.0,\n  "relative_P_200": 0.0,\n  "relative_P_500": 0.0,\n  "relative_P_1000": 0.0,\n  "success_1": 0.0,\n  "success_5": 0.0,\n  "success_10": 0.0,\n  "set_P": 0.0,\n  "set_relative_P": 0.0,\n  "set_recall": 0.0,\n  "set_map": 0.0,\n  "set_F": 0.0,\n  "num_nonrel_judged_ret": 0.0\n },\n "52": {\n  "runid": 0.0,\n  "num_q": 1.0,\n  "num_ret": 12.0,\n  "num_rel": 533.0,\n  "num_rel_ret": 0.0,\n  "map": 0.0,\n  "gm_map": -11.512925464970229,\n  "Rprec": 0.0,\n  "bpref": 0.0,\n  "recip_rank": 0.0,\n  "iprec_at_recall_0.00": 0.0,\n  "iprec_at_recall_0.10": 0.0,\n  "iprec_at_recall_0.20": 0.0,\n  "iprec_at_recall_0.30": 0.0,\n  "iprec_at_recall_0.40": 0.0,\n  "iprec_at_recall_0.50": 0.0,\n  "iprec_at_recall_0.60": 0.0,\n  "iprec_at_recall_0.70": 0.0,\n  "iprec_at_recall_0.80": 0.0,\n  "iprec_at_recall_0.90": 0.0,\n  "iprec_at_recall_1.00": 0.0,\n  "P_5": 0.0,\n  "P_10": 0.0,\n  "P_15": 0.0,\n  "P_20": 0.0,\n  "P_30": 0.0,\n  "P_100": 0.0,\n  "P_200": 0.0,\n  "P_500": 0.0,\n  "P_1000": 0.0,\n  "relstring": 0.0,\n  "recall_5": 0.0,\n  "recall_10": 0.0,\n  "recall_15": 0.0,\n  "recall_20": 0.0,\n  "recall_30": 0.0,\n  "recall_100": 0.0,\n  "recall_200": 0.0,\n  "recall_500": 0.0,\n  "recall_1000": 0.0,\n  "infAP": 0.0,\n  "gm_bpref": -11.512925464970229,\n  "Rprec_mult_0.20": 0.0,\n  "Rprec_mult_0.40": 0.0,\n  "Rprec_mult_0.60": 0.0,\n  "Rprec_mult_0.80": 0.0,\n  "Rprec_mult_1.00": 0.0,\n  "Rprec_mult_1.20": 0.0,\n  "Rprec_mult_1.40": 0.0,\n  "Rprec_mult_1.60": 0.0,\n  "Rprec_mult_1.80": 0.0,\n  "Rprec_mult_2.00": 0.0,\n  "utility": -12.0,\n  "11pt_avg": 0.0,\n  "binG": 0.0,\n  "G": 0.0,\n  "ndcg": 0.0,\n  "ndcg_rel": 0.0,\n  "Rndcg": 0.0,\n  "ndcg_cut_5": 0.0,\n  "ndcg_cut_10": 0.0,\n  "ndcg_cut_15": 0.0,\n  "ndcg_cut_20": 0.0,\n  "ndcg_cut_30": 0.0,\n  "ndcg_cut_100": 0.0,\n  "ndcg_cut_200": 0.0,\n  "ndcg_cut_500": 0.0,\n  "ndcg_cut_1000": 0.0,\n  "map_cut_5": 0.0,\n  "map_cut_10": 0.0,\n  "map_cut_15": 0.0,\n  "map_cut_20": 0.0,\n  "map_cut_30": 0.0,\n  "map_cut_100": 0.0,\n  "map_cut_200": 0.0,\n  "map_cut_500": 0.0,\n  "map_cut_1000": ...
